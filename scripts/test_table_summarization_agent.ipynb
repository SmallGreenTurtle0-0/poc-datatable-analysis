# %%
import os
import sys

sys.path.append(os.path.abspath("D:/WorkSpace/ChiHa/poc-datatable-analysis"))
# %cd D:/WorkSpace/ChiHa/poc-datatable-analysis
# Out:
# D:\WorkSpace\ChiHa\poc-datatable-analysis
# d:\anaconda\envs\ai_agent\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from app.externals.agents.table_summarization.workflow_manager import Workflow 
table_summarization_agent = Workflow()
table_summarization_agent.display_graph(table_summarization_agent.graph)
# Out:
# 2025-03-03 20:19:44.903 | INFO     | app.configs.settings:_initialize:21 - Initializing settings
# 2025-03-03 20:19:44.905 | INFO     | app.configs.settings:_initialize:23 - Settings successfully loaded.
# 2025-03-03 20:19:44.907 | INFO     | app.configs.llm:_init_llm_gpt_4o_mini:11 - Initialize OpenAI Chat GPT
# 2025-03-03 20:19:45.644 | INFO     | app.configs.llm:_init_llm_llama_32:27 - Initialize Ollama: model Llama 3.2
# d:\anaconda\envs\ai_agent\Lib\site-packages\pydantic\_internal\_generate_schema.py:502: UserWarning: typing.NotRequired is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(
# d:\anaconda\envs\ai_agent\Lib\site-packages\pydantic\_internal\_generate_schema.py:502: UserWarning: typing.NotRequired is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
result = await table_summarization_agent.run_agent(
    question="Give me brief summary about the data table"
)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = await table_summarization_agent.run_agent(
#       2     question="Give me brief summary about the data table"
#       3 )
#
# File D:\WorkSpace\ChiHa\poc-datatable-analysis\app\externals\agents\table_summarization\workflow_manager.py:59, in Workflow.run_agent(self, *args, **kwds)
#      57 async def run_agent(self, *args: Any, **kwds: Any):
#      58     """Execute the workflow and return the result."""
# ---> 59     result = await self.graph.ainvoke(
#      60         kwds,
#      61     )
#      62     return result
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\pregel\__init__.py:1613, in Pregel.ainvoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1611 else:
#    1612     chunks = []
# -> 1613 async for chunk in self.astream(
#    1614     input,
#    1615     config,
#    1616     stream_mode=stream_mode,
#    1617     output_keys=output_keys,
#    1618     interrupt_before=interrupt_before,
#    1619     interrupt_after=interrupt_after,
#    1620     debug=debug,
#    1621     **kwargs,
#    1622 ):
#    1623     if stream_mode == "values":
#    1624         latest = chunk
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\pregel\__init__.py:1502, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1491 # Similarly to Bulk Synchronous Parallel / Pregel model
#    1492 # computation proceeds in steps, while there are channel updates
#    1493 # channel updates from step N are only visible in step N+1
#    1494 # channels are guaranteed to be immutable for the duration of the step,
#    1495 # with channel updates applied only at the transition between steps
#    1496 while loop.tick(
#    1497     input_keys=self.input_channels,
#    1498     interrupt_before=interrupt_before_,
#    1499     interrupt_after=interrupt_after_,
#    1500     manager=run_manager,
#    1501 ):
# -> 1502     async for _ in runner.atick(
#    1503         loop.tasks.values(),
#    1504         timeout=self.step_timeout,
#    1505         retry_policy=self.retry_policy,
#    1506         get_waiter=get_waiter,
#    1507     ):
#    1508         # emit output
#    1509         for o in output():
#    1510             yield o
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\pregel\runner.py:130, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     128 t = tasks[0]
#     129 try:
# --> 130     await arun_with_retry(t, retry_policy, stream=self.use_astream)
#     131     self.commit(t, None)
#     132 except Exception as exc:
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\pregel\retry.py:102, in arun_with_retry(task, retry_policy, stream)
#     100         pass
#     101 else:
# --> 102     await task.proc.ainvoke(task.input, config)
#     103 # if successful, end
#     104 break
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\utils\runnable.py:452, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     450     coro = step.ainvoke(input, config)
#     451 if ASYNCIO_ACCEPTS_CONTEXT:
# --> 452     input = await asyncio.create_task(coro, context=context)
#     453 else:
#     454     input = await asyncio.create_task(coro)
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langgraph\utils\runnable.py:235, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     233 if ASYNCIO_ACCEPTS_CONTEXT:
#     234     coro = cast(Coroutine[None, None, Any], self.afunc(input, **kwargs))
# --> 235     ret = await asyncio.create_task(coro, context=context)
#     236 else:
#     237     ret = await self.afunc(input, **kwargs)
#
# File D:\WorkSpace\ChiHa\poc-datatable-analysis\app\externals\agents\table_summarization\table_summarization_agent.py:51, in TableSummarizationAgent.summarize(self, state)
#      49 prompt_template = PromptTemplate.from_template(SUMMARY_DATA_TABLE)
#      50 runnable = self.llm_manager.get_runnable(prompt=prompt_template)
# ---> 51 summarization = await runnable.ainvoke(
#      52     {
#      53         'question': state.get('question'),
#      54         'schema_info': state.get('schema_info'),
#      55         'table': state.get('table'),
#      56     },
#      57 )
#      58 state.update({
#      59     'response': summarization,
#      60 })
#      61 return state
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\runnables\base.py:3066, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3064     part = functools.partial(step.ainvoke, input, config)
#    3065 if asyncio_accepts_context():
# -> 3066     input = await asyncio.create_task(part(), context=context)  # type: ignore
#    3067 else:
#    3068     input = await asyncio.create_task(part())
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\runnables\fallbacks.py:235, in RunnableWithFallbacks.ainvoke(self, input, config, **kwargs)
#     233 coro = runnable.ainvoke(input, child_config, **kwargs)
#     234 if asyncio_accepts_context():
# --> 235     output = await asyncio.create_task(coro, context=context)  # type: ignore
#     236 else:
#     237     output = await coro
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\language_models\chat_models.py:305, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     296 async def ainvoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
# --> 305     llm_result = await self.agenerate_prompt(
#     306         [self._convert_input(input)],
#     307         stop=stop,
#     308         callbacks=config.get("callbacks"),
#     309         tags=config.get("tags"),
#     310         metadata=config.get("metadata"),
#     311         run_name=config.get("run_name"),
#     312         run_id=config.pop("run_id", None),
#     313         **kwargs,
#     314     )
#     315     return cast(ChatGeneration, llm_result.generations[0][0]).message
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\language_models\chat_models.py:870, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     862 async def agenerate_prompt(
#     863     self,
#     864     prompts: list[PromptValue],
#    (...)
#     867     **kwargs: Any,
#     868 ) -> LLMResult:
#     869     prompt_messages = [p.to_messages() for p in prompts]
# --> 870     return await self.agenerate(
#     871         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     872     )
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\language_models\chat_models.py:796, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     776 callback_manager = AsyncCallbackManager.configure(
#     777     callbacks,
#     778     self.callbacks,
#    (...)
#     783     self.metadata,
#     784 )
#     786 run_managers = await callback_manager.on_chat_model_start(
#     787     self._serialized,
#     788     messages,
#    (...)
#     793     run_id=run_id,
#     794 )
# --> 796 results = await asyncio.gather(
#     797     *[
#     798         self._agenerate_with_cache(
#     799             m,
#     800             stop=stop,
#     801             run_manager=run_managers[i] if run_managers else None,
#     802             **kwargs,
#     803         )
#     804         for i, m in enumerate(messages)
#     805     ],
#     806     return_exceptions=True,
#     807 )
#     808 exceptions = []
#     809 for i, res in enumerate(results):
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_core\language_models\chat_models.py:998, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#     996 else:
#     997     if inspect.signature(self._agenerate).parameters.get("run_manager"):
# --> 998         result = await self._agenerate(
#     999             messages, stop=stop, run_manager=run_manager, **kwargs
#    1000         )
#    1001     else:
#    1002         result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_ollama\chat_models.py:788, in ChatOllama._agenerate(self, messages, stop, run_manager, **kwargs)
#     781 async def _agenerate(
#     782     self,
#     783     messages: List[BaseMessage],
#    (...)
#     786     **kwargs: Any,
#     787 ) -> ChatResult:
# --> 788     final_chunk = await self._achat_stream_with_aggregation(
#     789         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     790     )
#     791     generation_info = final_chunk.generation_info
#     792     chat_generation = ChatGeneration(
#     793         message=AIMessage(
#     794             content=final_chunk.text,
#    (...)
#     798         generation_info=generation_info,
#     799     )
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_ollama\chat_models.py:645, in ChatOllama._achat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     636 async def _achat_stream_with_aggregation(
#     637     self,
#     638     messages: List[BaseMessage],
#    (...)
#     642     **kwargs: Any,
#     643 ) -> ChatGenerationChunk:
#     644     final_chunk = None
# --> 645     async for stream_resp in self._acreate_chat_stream(messages, stop, **kwargs):
#     646         if not isinstance(stream_resp, str):
#     647             chunk = ChatGenerationChunk(
#     648                 message=AIMessageChunk(
#     649                     content=(
#    (...)
#     662                 ),
#     663             )
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\langchain_ollama\chat_models.py:575, in ChatOllama._acreate_chat_stream(self, messages, stop, **kwargs)
#     572 chat_params = self._chat_params(messages, stop, **kwargs)
#     574 if chat_params["stream"]:
# --> 575     async for part in await self._async_client.chat(**chat_params):
#     576         yield part
#     577 else:
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\ollama\_client.py:674, in AsyncClient._request.<locals>.inner()
#     671   await e.response.aread()
#     672   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 674 async for line in r.aiter_lines():
#     675   part = json.loads(line)
#     676   if err := part.get('error'):
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_models.py:1031, in Response.aiter_lines(self)
#    1029 decoder = LineDecoder()
#    1030 with request_context(request=self._request):
# -> 1031     async for text in self.aiter_text():
#    1032         for line in decoder.decode(text):
#    1033             yield line
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_models.py:1018, in Response.aiter_text(self, chunk_size)
#    1016 chunker = TextChunker(chunk_size=chunk_size)
#    1017 with request_context(request=self._request):
# -> 1018     async for byte_content in self.aiter_bytes():
#    1019         text_content = decoder.decode(byte_content)
#    1020         for chunk in chunker.decode(text_content):
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_models.py:997, in Response.aiter_bytes(self, chunk_size)
#     995 chunker = ByteChunker(chunk_size=chunk_size)
#     996 with request_context(request=self._request):
# --> 997     async for raw_bytes in self.aiter_raw():
#     998         decoded = decoder.decode(raw_bytes)
#     999         for chunk in chunker.decode(decoded):
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_models.py:1055, in Response.aiter_raw(self, chunk_size)
#    1052 chunker = ByteChunker(chunk_size=chunk_size)
#    1054 with request_context(request=self._request):
# -> 1055     async for raw_stream_bytes in self.stream:
#    1056         self._num_bytes_downloaded += len(raw_stream_bytes)
#    1057         for chunk in chunker.decode(raw_stream_bytes):
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_client.py:176, in BoundAsyncStream.__aiter__(self)
#     175 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
# --> 176     async for chunk in self._stream:
#     177         yield chunk
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpx\_transports\default.py:271, in AsyncResponseStream.__aiter__(self)
#     269 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
#     270     with map_httpcore_exceptions():
# --> 271         async for part in self._httpcore_stream:
#     272             yield part
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\connection_pool.py:407, in PoolByteStream.__aiter__(self)
#     405 except BaseException as exc:
#     406     await self.aclose()
# --> 407     raise exc from None
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\connection_pool.py:403, in PoolByteStream.__aiter__(self)
#     401 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
#     402     try:
# --> 403         async for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\http11.py:342, in HTTP11ConnectionByteStream.__aiter__(self)
#     340 with AsyncShieldCancellation():
#     341     await self.aclose()
# --> 342 raise exc
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\http11.py:334, in HTTP11ConnectionByteStream.__aiter__(self)
#     332 try:
#     333     async with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         async for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\http11.py:203, in AsyncHTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = await self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_async\http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File d:\anaconda\envs\ai_agent\Lib\site-packages\anyio\_backends\_asyncio.py:1203, in SocketStream.receive(self, max_bytes)
#    1198 if (
#    1199     not self._protocol.read_event.is_set()
#    1200     and not self._transport.is_closing()
#    1201 ):
#    1202     self._transport.resume_reading()
# -> 1203     await self._protocol.read_event.wait()
#    1204     self._transport.pause_reading()
#    1206 try:
#
# File d:\anaconda\envs\ai_agent\Lib\asyncio\locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:

# %%
print(result["response"].content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(result["response"].content)
#
# AttributeError: 'str' object has no attribute 'content'
